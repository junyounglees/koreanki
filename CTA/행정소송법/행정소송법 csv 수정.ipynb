# %%
import pandas as pd
df = pd.read_csv("/Users/junyounglee/github_repos/koreanki/CTA/행정소송법/Selected Notes.csv", header=None)

# %%
n = []
for i in df.loc[:,1]:
    if i[0] == '<':
        n.append(i)
    else:
        i = "<span style=color: rgb(21, 21, 148); font-weight: bold;>"+i+"</span>"
        n.append(i)

# %%
df.to_csv("/Users/junyounglee/github_repos/koreanki/CTA/행정소송법/Selected Notes.csv", header=None, index=False)

# %%
df2 = pd.read_csv("/Users/junyounglee/github_repos/koreanki/CTA/행정소송법/행정소송법 법령 csv(참고용).csv", header=None)

# %%
df2
# Out:
#                                                     0  \
# 0   제1조（목적） 이 법은 행정소송절차를 통하여 {{c1::행정청}}의 {{c2::위법...
# 1   제2조（정의） ① 이 법에서 사용하는 용어의 정의는 다음과 같다.<br>1. “{{...
# 2   제3조（행정소송의 종류） 행정소송은 다음의 네가지로 구분한다.〈개정 1988.8.5...
# 3   제4조（항고소송） 항고소송은 다음과 같이 구분한다. <br>1. 취소소송 : {{c...
# 4   "<span style=""color: rgb(21, 21, 148); font-w...
# 5   "<div><span style=""color: rgb(21, 21, 148); f...
# 6   "<span style=""color: rgb(21, 21, 148); font-w...
# 7   "<div><span style=""color: rgb(21, 21, 148); f...
# 8   "<div><span style=""color: rgb(21, 21, 148); f...
# 9   "<div><span style=""color: rgb(21, 21, 148); f...
# 10  "<div><span style=""color: rgb(21, 21, 148); f...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...
